# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ## Gensim LDA (Latent Dirichlet Allocation)

# %%
import numpy as np
import pandas as pd
import dataframe_image as dfi

import nltk
from nltk.corpus import stopwords

import sys
import os

import gensim
from gensim.models import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora.dictionary import Dictionary
from gensim.matutils import corpus2csc

from pprint import pprint

import pyLDAvis
import pyLDAvis.gensim_models
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

import tqdm

import tomotopy as tp

from preprocess import preprocess, tokenizer, stopword_list

# %%
data_root = '../data/cvt/'
df = pd.read_csv(os.path.join(data_root, 'covidvaccine.csv'))
df
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                              user_name               user_location  \
# 0                               Ashwin                    India 🇮🇳
# 1                        K. Kartik Rao     Mumbai and Nagpur India
# 2       Mac Patrick (Road Hater) Henry       German Bundesrepublik
# 3                           lydia Bell                      Earth
# 4                      Lou Ann Donovan                 Kansas, USA
# ...                                ...                         ...
# 154533          Script Your Future '21                         DMV
# 154534                  eastvillagetwt  East Village, New York, NY
# 154535                          Yogita                New York, NY
# 154536                             DrZ                         USA
# 154537                   vaccinesearch                         NaN
#
#                                          user_description  \
# 0       I'm Just A Man On a Mission For My Vision!\n\n...
# 1       Actor 🎭 \n\nhttps://t.co/u7GZfoWBDt\n\nSubscri...
# 2       Liberty lover. \nServing the people of the 🇺🇸....
# 3       Mummy, animal lover , energy worker , awake in...
# 4       Live Young Look Young BE Young! Certified Inte...
# ...                                                   ...
# 154533  HowardU and Script Your Future has joined forc...
# 154534  Politics, the environment, science, culture, t...
# 154535  Primum non nocere 💕👩🏽‍⚕️ | Tweets are my own. ...
# 154536                                                NaN
# 154537  Hit Me With Your Best Shot - Pat Benatar. Tale...
#
#                user_created  user_followers  user_friends  user_favourites  \
# 0       2018-01-08 06:01:00            89.0        3108.0           6780.0
# 1       2016-12-10 16:06:00           225.0         257.0          25362.0
# 2       2014-01-11 19:47:00           338.0         277.0          28305.0
# 3       2009-03-23 01:09:00          2038.0        1105.0          63422.0
# 4       2009-03-17 05:42:00          4365.0        4581.0           2505.0
# ...                     ...             ...           ...              ...
# 154533  2021-01-31 18:40:41            15.0          42.0              4.0
# 154534  2011-08-27 19:24:17          1968.0        5001.0         136110.0
# 154535  2015-08-07 01:48:57            17.0          58.0           1194.0
# 154536  2016-03-23 13:00:36            54.0           4.0              4.0
# 154537  2021-02-18 06:03:14            83.0          39.0             81.0
#
#         user_verified                 date  \
# 0                   0  2020-08-09 19:15:00
# 1                   0  2020-08-09 20:02:00
# 2                   0  2020-08-09 21:21:00
# 3                   0  2020-08-09 21:29:00
# 4                   0  2020-08-09 22:55:00
# ...               ...                  ...
# 154533              0  2021-02-28 23:55:25
# 154534              0  2021-02-28 23:56:37
# 154535              0  2021-02-28 23:57:00
# 154536              0  2021-02-28 23:57:06
# 154537              0  2021-02-28 23:57:15
#
#                                                      text  \
# 0       Huge Thanks And Best Wishes With @SerumInstInd...
# 1                        Any update of #CovidVaccine ????
# 2       From a private frontline COVID nurses group to...
# 3       So you want the whole world to take a #covidva...
# 4       Watch to learn about the Phase 3 clinical tria...
# ...                                                   ...
# 154533  * Continue with routine preventive measures (s...
# 154534  COVID: California Suspends System Of Shared Va...
# 154535  Today I got my first dose of the #COVIDVaccine...
# 154536  Here's Where to Receive a COVID Vaccine in Ill...
# 154537  Utah!! SLC is sold out. Walmart vaccine. **onl...
#
#                                               hashtags               source  \
# 0                                           covisheild  Twitter for Android
# 1                                         covidvaccine  Twitter for Android
# 2       covid19 covidvaccinerace covidvaccine pandemic      Twitter Web App
# 3                                         covidvaccine   Twitter for iPhone
# 4              covid19 covidvaccine covidclinicaltrial   Twitter for iPhone
# ...                                                ...                  ...
# 154533                                             NaN      Twitter Web App
# 154534                            covid19 covidvaccine   Twitter for iPhone
# 154535                                    covidvaccine  Twitter for Android
# 154536                           illinois covidvaccine               Buffer
# 154537                                             NaN      Twitter Web App
#
#         hashtag_count
# 0                   1
# 1                   1
# 2                   4
# 3                   1
# 4                   3
# ...               ...
# 154533              0
# 154534              2
# 154535              1
# 154536              2
# 154537              0
#
# [154538 rows x 13 columns]

# %%
df['text'] = df['text'].apply(lambda x: preprocess(x))

df
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                              user_name               user_location  \
# 0                               Ashwin                    India 🇮🇳
# 1                        K. Kartik Rao     Mumbai and Nagpur India
# 2       Mac Patrick (Road Hater) Henry       German Bundesrepublik
# 3                           lydia Bell                      Earth
# 4                      Lou Ann Donovan                 Kansas, USA
# ...                                ...                         ...
# 154533          Script Your Future '21                         DMV
# 154534                  eastvillagetwt  East Village, New York, NY
# 154535                          Yogita                New York, NY
# 154536                             DrZ                         USA
# 154537                   vaccinesearch                         NaN
#
#                                          user_description  \
# 0       I'm Just A Man On a Mission For My Vision!\n\n...
# 1       Actor 🎭 \n\nhttps://t.co/u7GZfoWBDt\n\nSubscri...
# 2       Liberty lover. \nServing the people of the 🇺🇸....
# 3       Mummy, animal lover , energy worker , awake in...
# 4       Live Young Look Young BE Young! Certified Inte...
# ...                                                   ...
# 154533  HowardU and Script Your Future has joined forc...
# 154534  Politics, the environment, science, culture, t...
# 154535  Primum non nocere 💕👩🏽‍⚕️ | Tweets are my own. ...
# 154536                                                NaN
# 154537  Hit Me With Your Best Shot - Pat Benatar. Tale...
#
#                user_created  user_followers  user_friends  user_favourites  \
# 0       2018-01-08 06:01:00            89.0        3108.0           6780.0
# 1       2016-12-10 16:06:00           225.0         257.0          25362.0
# 2       2014-01-11 19:47:00           338.0         277.0          28305.0
# 3       2009-03-23 01:09:00          2038.0        1105.0          63422.0
# 4       2009-03-17 05:42:00          4365.0        4581.0           2505.0
# ...                     ...             ...           ...              ...
# 154533  2021-01-31 18:40:41            15.0          42.0              4.0
# 154534  2011-08-27 19:24:17          1968.0        5001.0         136110.0
# 154535  2015-08-07 01:48:57            17.0          58.0           1194.0
# 154536  2016-03-23 13:00:36            54.0           4.0              4.0
# 154537  2021-02-18 06:03:14            83.0          39.0             81.0
#
#         user_verified                 date  \
# 0                   0  2020-08-09 19:15:00
# 1                   0  2020-08-09 20:02:00
# 2                   0  2020-08-09 21:21:00
# 3                   0  2020-08-09 21:29:00
# 4                   0  2020-08-09 22:55:00
# ...               ...                  ...
# 154533              0  2021-02-28 23:55:25
# 154534              0  2021-02-28 23:56:37
# 154535              0  2021-02-28 23:57:00
# 154536              0  2021-02-28 23:57:06
# 154537              0  2021-02-28 23:57:15
#
#                                                      text  \
# 0       huge thanks best wishes seruminstindia adarpoo...
# 1                                     update covidvaccine
# 2       private frontline covid nurses group today cov...
# 3       want whole world take covidvaccine s fast trac...
# 4       watch learn phase clinical trial covid vaccine...
# ...                                                   ...
# 154533  continue routine preventive measures vaccinati...
# 154534  covid california suspends system shared vaccin...
# 154535   today got first dose covidvaccine super thankful
# 154536  heres receive covid vaccine illinois illinois ...
# 154537  utah slc sold walmart vaccine first dose book ...
#
#                                               hashtags               source  \
# 0                                           covisheild  Twitter for Android
# 1                                         covidvaccine  Twitter for Android
# 2       covid19 covidvaccinerace covidvaccine pandemic      Twitter Web App
# 3                                         covidvaccine   Twitter for iPhone
# 4              covid19 covidvaccine covidclinicaltrial   Twitter for iPhone
# ...                                                ...                  ...
# 154533                                             NaN      Twitter Web App
# 154534                            covid19 covidvaccine   Twitter for iPhone
# 154535                                    covidvaccine  Twitter for Android
# 154536                           illinois covidvaccine               Buffer
# 154537                                             NaN      Twitter Web App
#
#         hashtag_count
# 0                   1
# 1                   1
# 2                   4
# 3                   1
# 4                   3
# ...               ...
# 154533              0
# 154534              2
# 154535              1
# 154536              2
# 154537              0
#
# [154538 rows x 13 columns]

# %%
df['text']
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0         huge thanks best wishes seruminstindia adarpoo...
# 1                                       update covidvaccine
# 2         private frontline covid nurses group today cov...
# 3         want whole world take covidvaccine s fast trac...
# 4         watch learn phase clinical trial covid vaccine...
#                                 ...
# 154533    continue routine preventive measures vaccinati...
# 154534    covid california suspends system shared vaccin...
# 154535     today got first dose covidvaccine super thankful
# 154536    heres receive covid vaccine illinois illinois ...
# 154537    utah slc sold walmart vaccine first dose book ...
# Name: text, Length: 154538, dtype: object

# %%
# Prepare corpus
def get_tp_corpus(docs):
    porter_stemmer = nltk.PorterStemmer().stem
    english_stops = set(porter_stemmer(w) for w in stopwords.words('english'))
    tp_corpus = tp.utils.Corpus(
        tokenizer=tp.utils.SimpleTokenizer(porter_stemmer), 
        stopwords=lambda x: x in english_stops
    )
    tp_corpus.process(d.lower() for d in docs)
    return tp_corpus

tp_corpus = get_tp_corpus(list(df['text']))
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def compute_coherence_values_tp(tp_corpus, k, a, b):
    lda_model = tp.LDAModel(k=k,alpha=a,eta=b,corpus=tp_corpus)
    lda_model.train(500)
    co_mass = tp.coherence.Coherence(lda_model,coherence="u_mass")
    co_cv = tp.coherence.Coherence(lda_model,coherence="c_v")
    return co_mass.get_score(), co_cv.get_score()
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
already_run = True

# Topics range (length = 10)
min_topics = 2
max_topics = 22
step_size = 1
topics_range = range(min_topics, max_topics, step_size)

# Alpha parameter (length = 5)
alpha = list(np.arange(0.01, 1, 0.1))

# Beta parameter (length = 5)
beta = list(np.arange(0.01, 1, 0.1))

model_results = {'Topics': [],
                 'Alpha': [],
                 'Beta': [],
                 'Coherence_cv': [],
                 "Coherence_umass":[],
                }

if not already_run:
    # Can take a long time to run
    pbar = tqdm.tqdm(total=2200)
    
    # Iterate through number of topics
    for k in topics_range:
        # Iterate through alpha values
        for a in alpha:
            # Iterate through beta values
            for b in beta:
                # Get the coherence score for the given parameters
                umass,cv = compute_coherence_values_tp(tp_corpus=tp_corpus,k=k, a=a, b=b)
                #print(umass,cv)
                # Save the model results
                model_results['Topics'].append(k)
                model_results['Alpha'].append(a)
                model_results['Beta'].append(b)
                model_results['Coherence_cv'].append(cv)
                model_results['Coherence_umass'].append(umass)


                pbar.update(1)
                coherence_results = pd.DataFrame(model_results)
                coherence_results.to_csv('../out/lda_tuning_results.csv', index=False)
    pbar.close()
else:
    coherence_results = pd.read_csv('../out/lda_tuning_results.csv')
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Sort coherence_results
sorted_coherence_results = coherence_results.sort_values(by=['Coherence_cv', 'Coherence_umass'], ascending=False)
sorted_coherence_results
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       Topics  Alpha  Beta  Coherence_cv  Coherence_umass
# 1809      20   0.01  0.91      0.934071       -12.548957
# 1879      20   0.71  0.91      0.933534       -11.583615
# 1888      20   0.81  0.81      0.933502       -12.632436
# 1839      20   0.31  0.91      0.933187       -14.247271
# 1949      21   0.41  0.91      0.932608       -12.058181
# ...      ...    ...   ...           ...              ...
# 17         2   0.11  0.71      0.307607        -2.794608
# 7          2   0.01  0.71      0.307535        -2.925011
# 112        3   0.11  0.21      0.307470        -2.948469
# 6          2   0.01  0.61      0.306032        -2.824641
# 70         2   0.71  0.01      0.304783        -2.703759
#
# [2000 rows x 5 columns]

# %%
dfi.export(sorted_coherence_results, '../img/sorted_lda_coherence_results.png', max_rows=10)
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# View the top coherence result
best_hyperparams = sorted_coherence_results.iloc[0]
best_hyperparams
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Topics             20.000000
# Alpha               0.010000
# Beta                0.910000
# Coherence_cv        0.934071
# Coherence_umass   -12.548957
# Name: 1809, dtype: float64

# %%
mdl = tp.LDAModel(
    k=int(best_hyperparams['Topics']),
    corpus=tp_corpus,
    alpha=best_hyperparams['Alpha'],
    eta=best_hyperparams['Beta']
)

mdl.train(500)
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
mdl.summary()

topic_term_dists = np.stack([mdl.get_topic_word_dist(k) for k in range(mdl.k)])
doc_topic_dists = np.stack([doc.get_topic_dist() for doc in mdl.docs])
doc_topic_dists /= doc_topic_dists.sum(axis=1, keepdims=True)
doc_lengths = np.array([len(doc.words) for doc in mdl.docs])
vocab = list(mdl.used_vocabs)
term_frequency = mdl.used_vocab_freq

prepared_data = pyLDAvis.prepare(
    topic_term_dists, 
    doc_topic_dists, 
    doc_lengths, 
    vocab, 
    term_frequency
)

pyLDAvis.save_html(prepared_data, '../out/ldavis.html')
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <Basic Info>
# | LDAModel (current version: 0.11.1)
# | 154535 docs, 1531044 words
# | Total Vocabs: 76786, Used Vocabs: 76786
# | Entropy of words: -7.72703
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 500, Burn-in steps: 0
# | Optimization Interval: 10
# | Log-likelihood per word: -8.09952
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k: 20 (the number of topics between 1 ~ 32767)
# | alpha: [0.01] (hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k` of `float` in case of asymmetric prior.)
# | eta: 0.91 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 4140643104 (random seed)
# | trained in version 0.11.1
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document topic distributions)
# |  [3.5813826e-04 1.5189136e-04 5.2425326e-05 1.1932670e-04 2.7304762e-03
# |   5.9657399e-05 6.6888882e-05 4.5148619e-03 3.8213521e-01 6.8696914e-05
# |   9.2201401e-05 2.2242851e-04 3.7987009e-04 1.5132937e-03 1.3503399e-03
# |   1.9891070e-04 4.3386084e-05 2.0976680e-04 2.1993499e-01 5.1374524e-03]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.91
# |
# <Topics>
# | #0 (1095) : rabbi sold srqcountygov utter chao
# | #1 (519) : inner insert x gay cushion
# | #2 (159) : datasci deeplearn machinelearn artificialintellig daysofcod
# | #3 (337) : dboss roberrt spreadboss sarkaruvaaripaata maheshbabu
# | #4 (6312) : largestvaccinedr share experi district shri
# | #5 (170) : cnnafrica france_en ajenglish bbcafrica dwnew
# | #6 (197) : upwards_button dronkarsahotaam navinshah cityhallabour unmeshdesai
# | #7 (9506) : signific cross mileston bangladesh day
# | #8 (935494) : covidvaccin vaccin covid get peopl
# | #9 (193) : organiz chart templat hierarchi bigdata
# | #10 (236) : hpm sheikhhasina shortest bangladeshi arrang
# | #11 (760) : trav safest transfer afford taxi
# | #12 (1274) : wors seduc wax shall men
# | #13 (4170) : educ redfor ape tbat top
# | #14 (3889) : mask wakefield glass genet modif
# | #15 (658) : hpm sheikhhasina shortest bangladeshi arrang
# | #16 (146) : vonderleyen eu_commiss cylebo eu_health brainstormcel
# | #17 (690) : footwearmal _ shop februari happynewmonth
# | #18 (554476) : covidvaccin vaccin get covid dose
# | #19 (10763) : year pleas postpon tokyoolymp parisolymp
# |

# %%
rows = {}

for i in range(int(best_hyperparams['Topics'])):
    topic_words = mdl.get_topic_words(i)
    rows['Topic #' + str(i)] = [w for w, p in topic_words]

topic_words = pd.DataFrame.from_dict(rows, orient='index',
                       columns=['Keyword #1', 'Keyword #2', 'Keyword #3', 'Keyword #4', 'Keyword #5',
                               'Keyword #6', 'Keyword #7', 'Keyword #8', 'Keyword #9', 'Keyword #10'])
topic_words
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                  Keyword #1       Keyword #2    Keyword #3  \
# Topic #0              rabbi             sold  srqcountygov
# Topic #1              inner           insert             x
# Topic #2            datasci        deeplearn  machinelearn
# Topic #3              dboss          roberrt    spreadboss
# Topic #4   largestvaccinedr            share        experi
# Topic #5          cnnafrica        france_en     ajenglish
# Topic #6     upwards_button  dronkarsahotaam     navinshah
# Topic #7           signific            cross      mileston
# Topic #8        covidvaccin           vaccin         covid
# Topic #9            organiz            chart       templat
# Topic #10               hpm     sheikhhasina      shortest
# Topic #11              trav           safest      transfer
# Topic #12              wors            seduc           wax
# Topic #13              educ           redfor           ape
# Topic #14              mask        wakefield         glass
# Topic #15               hpm     sheikhhasina      shortest
# Topic #16       vonderleyen       eu_commiss        cylebo
# Topic #17       footwearmal                _          shop
# Topic #18       covidvaccin           vaccin           get
# Topic #19              year            pleas       postpon
#
#                    Keyword #4     Keyword #5       Keyword #6  \
# Topic #0                utter           chao           zorger
# Topic #1                  gay        cushion              pad
# Topic #2   artificialintellig      daysofcod             nspx
# Topic #3    sarkaruvaaripaata     maheshbabu           mcphif
# Topic #4             district           shri          nowplay
# Topic #5            bbcafrica          dwnew       covidtrack
# Topic #6        cityhallabour    unmeshdesai    krupeshhirani
# Topic #7           bangladesh            day           record
# Topic #8                  get          peopl       coronaviru
# Topic #9            hierarchi        bigdata    digitalmarket
# Topic #10         bangladeshi         arrang         thankyou
# Topic #11              afford           taxi              fix
# Topic #12               shall            men             evil
# Topic #13                tbat            top              big
# Topic #14               genet          modif         irrevers
# Topic #15         bangladeshi         arrang               ge
# Topic #16           eu_health  brainstormcel    skyriakideseu
# Topic #17            februari  happynewmonth  thesaganadeclar
# Topic #18               covid           dose            today
# Topic #19          tokyoolymp     parisolymp          laolymp
#
#                   Keyword #7      Keyword #8      Keyword #9  \
# Topic #0           jerusalem            mosh          satmar
# Topic #1            stutenze           candi             von
# Topic #2             accumul            opti              ss
# Topic #3           bamatrack           match         wbrcnew
# Topic #4                join             smt          medicr
# Topic #5               repli         ganpati      kylenabeck
# Topic #6       asianvoicenew      harrow_tim        jaketapp
# Topic #7                song            sinc         million
# Topic #8              pfizer             say            take
# Topic #9              keynot         startup   grandpasnarki
# Topic #10                 ge  pushpashivaram  seiucalifornia
# Topic #11              black         comfort           price
# Topic #12             deceiv         timothi      commongood
# Topic #13  white_large_squar          banana         headlin
# Topic #14            premium           foggi        flamingo
# Topic #15           thankyou           lucki            time
# Topic #16            ema_new     europarl_en        raj_psyc
# Topic #17      downingstreet   houseofcommon        mojgovuk
# Topic #18              first             got           thank
# Topic #19              hello          nbcnew               _
#
#                    Keyword #10
# Topic #0                  wolf
# Topic #1               patrick
# Topic #2                   low
# Topic #3             warondumb
# Topic #4        mondaynightibd
# Topic #5           patrickbyrn
# Topic #6                 sruhl
# Topic #7   face_with_thermomet
# Topic #8                 india
# Topic #9           saharamarir
# Topic #10          harjapbhang
# Topic #11               london
# Topic #12                  tim
# Topic #13                today
# Topic #14                 warn
# Topic #15            wordmandc
# Topic #16               csmoni
# Topic #17             ukparlia
# Topic #18               receiv
# Topic #19                janon

# %%
token_counts = mdl.get_count_by_topics()
topic_words.insert(0, 'Token Counts', token_counts)
topic_words
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            Token Counts        Keyword #1       Keyword #2    Keyword #3  \
# Topic #0           1095             rabbi             sold  srqcountygov
# Topic #1            519             inner           insert             x
# Topic #2            159           datasci        deeplearn  machinelearn
# Topic #3            337             dboss          roberrt    spreadboss
# Topic #4           6312  largestvaccinedr            share        experi
# Topic #5            170         cnnafrica        france_en     ajenglish
# Topic #6            197    upwards_button  dronkarsahotaam     navinshah
# Topic #7           9506          signific            cross      mileston
# Topic #8         935494       covidvaccin           vaccin         covid
# Topic #9            193           organiz            chart       templat
# Topic #10           236               hpm     sheikhhasina      shortest
# Topic #11           760              trav           safest      transfer
# Topic #12          1274              wors            seduc           wax
# Topic #13          4170              educ           redfor           ape
# Topic #14          3889              mask        wakefield         glass
# Topic #15           658               hpm     sheikhhasina      shortest
# Topic #16           146       vonderleyen       eu_commiss        cylebo
# Topic #17           690       footwearmal                _          shop
# Topic #18        554476       covidvaccin           vaccin           get
# Topic #19         10763              year            pleas       postpon
#
#                    Keyword #4     Keyword #5       Keyword #6  \
# Topic #0                utter           chao           zorger
# Topic #1                  gay        cushion              pad
# Topic #2   artificialintellig      daysofcod             nspx
# Topic #3    sarkaruvaaripaata     maheshbabu           mcphif
# Topic #4             district           shri          nowplay
# Topic #5            bbcafrica          dwnew       covidtrack
# Topic #6        cityhallabour    unmeshdesai    krupeshhirani
# Topic #7           bangladesh            day           record
# Topic #8                  get          peopl       coronaviru
# Topic #9            hierarchi        bigdata    digitalmarket
# Topic #10         bangladeshi         arrang         thankyou
# Topic #11              afford           taxi              fix
# Topic #12               shall            men             evil
# Topic #13                tbat            top              big
# Topic #14               genet          modif         irrevers
# Topic #15         bangladeshi         arrang               ge
# Topic #16           eu_health  brainstormcel    skyriakideseu
# Topic #17            februari  happynewmonth  thesaganadeclar
# Topic #18               covid           dose            today
# Topic #19          tokyoolymp     parisolymp          laolymp
#
#                   Keyword #7      Keyword #8      Keyword #9  \
# Topic #0           jerusalem            mosh          satmar
# Topic #1            stutenze           candi             von
# Topic #2             accumul            opti              ss
# Topic #3           bamatrack           match         wbrcnew
# Topic #4                join             smt          medicr
# Topic #5               repli         ganpati      kylenabeck
# Topic #6       asianvoicenew      harrow_tim        jaketapp
# Topic #7                song            sinc         million
# Topic #8              pfizer             say            take
# Topic #9              keynot         startup   grandpasnarki
# Topic #10                 ge  pushpashivaram  seiucalifornia
# Topic #11              black         comfort           price
# Topic #12             deceiv         timothi      commongood
# Topic #13  white_large_squar          banana         headlin
# Topic #14            premium           foggi        flamingo
# Topic #15           thankyou           lucki            time
# Topic #16            ema_new     europarl_en        raj_psyc
# Topic #17      downingstreet   houseofcommon        mojgovuk
# Topic #18              first             got           thank
# Topic #19              hello          nbcnew               _
#
#                    Keyword #10
# Topic #0                  wolf
# Topic #1               patrick
# Topic #2                   low
# Topic #3             warondumb
# Topic #4        mondaynightibd
# Topic #5           patrickbyrn
# Topic #6                 sruhl
# Topic #7   face_with_thermomet
# Topic #8                 india
# Topic #9           saharamarir
# Topic #10          harjapbhang
# Topic #11               london
# Topic #12                  tim
# Topic #13                today
# Topic #14                 warn
# Topic #15            wordmandc
# Topic #16               csmoni
# Topic #17             ukparlia
# Topic #18               receiv
# Topic #19                janon

# %%
topic_words.to_csv('../out/lda_topic_words.csv', index=True)
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
dfi.export(topic_words, '../img/lda_topic_words.png')
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
