# %% [markdown]
# # Exploratory Data Analysis: Covid Vaccine Tweet (CVT) Dataset

# %% [markdown]
# The tweets have #CovidVaccine hashtag. The collection started on 1/8/2020 and was downloaded from [Kaggle](https://www.kaggle.com/kaushiksuresh147/covidvaccine-tweets) on March 14, 2021.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

# %%
data_root = './data/cvt/'
df = pd.read_csv(os.path.join(data_root, 'raw_covidvaccine.csv'))
df
# Out:
# /home/andrewchen/anaconda3/envs/ml_proj/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (5,6,7,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                  user_name              user_location  \
# 0                                 MyNewsNE                      Assam
# 1                            Shubham Gupta                        NaN
# 2                  Journal of Infectiology                        NaN
# 3                                     Zane                        NaN
# 4                       Ann-Maree O’Connor  Adelaide, South Australia
# ...                                    ...                        ...
# 161246         Multivalent Dirk Haussecker                  RNA World
# 161247                    Craig Brown 🏳️‍🌈        Melbourne, Victoria
# 161248                   Faith in New York              New York, USA
# 161249  Openly Black & Queer & Adrian 🎵🎬⚖️                  In My Bag
# 161250                                 ⛄️🌈         SA & NT (rotation)
#
#                                          user_description  \
# 0       MyNewsNE a dedicated multi-lingual media house...
# 1       I will tell about all experiences of my life f...
# 2       Journal of Infectiology (ISSN 2689-9981) is ac...
# 3                                       Fresher than you.
# 4       Retired university administrator. Melburnian b...
# ...                                                   ...
# 161246  Biotech stock addict. Trained in RNAi. Love gr...
# 161247  writer. dad. husband. exvangelical. type 1. le...
# 161248  Building power in New York faith institutions ...
# 161249  CashApp $inga4hire 💰 // #MeToo Fellow //Spelma...
# 161250  The message is in the 'demeaning'.\nQuality co...
#
#                user_created  user_followers user_friends user_favourites  \
# 0          24-05-2020 10:18            64.0         11.0           110.0
# 1          14-08-2020 16:42             1.0         17.0             0.0
# 2          14-12-2017 07:07           143.0        566.0             8.0
# 3          18-09-2019 11:01            29.0         25.0           620.0
# 4          24-01-2013 14:53            83.0        497.0         10737.0
# ...                     ...             ...          ...             ...
# 161246  2011-11-10 12:00:58         11708.0          371            9176
# 161247  2012-06-20 16:47:27           397.0          838            9927
# 161248  2013-06-04 21:34:33          3122.0         2569            6663
# 161249  2009-09-16 15:33:00           460.0          523           30867
# 161250  2020-02-02 06:45:45           399.0          375           14188
#
#        user_verified                 date  \
# 0              False     18-08-2020 12:55
# 1              False     18-08-2020 12:55
# 2              False     18-08-2020 12:46
# 3              False     18-08-2020 12:45
# 4              False     18-08-2020 12:45
# ...              ...                  ...
# 161246         False  2021-03-11 22:30:23
# 161247         False  2021-03-11 22:30:05
# 161248         False  2021-03-11 22:29:58
# 161249         False  2021-03-11 22:29:56
# 161250         False  2021-03-11 22:29:54
#
#                                                      text  \
# 0       Australia to Manufacture Covid-19 Vaccine and ...
# 1       #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2       Deaths due to COVID-19 in Affected Countries\n...
# 3       @Team_Subhashree @subhashreesotwe @iamrajchoco...
# 4       @michellegrattan @ConversationEDU This is what...
# ...                                                   ...
# 161246  $ABUS totally missing in action. Nothing on mR...
# 161247  “It’s not a race,” says man already vaccinated...
# 161248  ⚠️PSA FOR COVID-19 VACCINE⚠️\n\nIf you live in...
# 161249  My doctor: Like to schedule your #CovidVaccine...
# 161250  @M_McCormackMP serves up a litany of excuses f...
#
#                                                  hashtags  \
# 0                                        ['CovidVaccine']
# 1       ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 161246                       ['covidvaccine', 'sarscov2']
# 161247  ['vaccine', 'auspol', 'CovidVaccine', 'ScottyF...
# 161248                                ['Bronx', 'Harlem']
# 161249                                   ['CovidVaccine']
# 161250                        ['LNPfail', 'CovidVaccine']
#
#                      source is_retweet
# 0           Twitter Web App      False
# 1       Twitter for Android      False
# 2           Twitter Web App      False
# 3       Twitter for Android      False
# 4           Twitter Web App      False
# ...                     ...        ...
# 161246      Twitter Web App      False
# 161247   Twitter for iPhone      False
# 161248   Twitter for iPhone      False
# 161249  Twitter for Android      False
# 161250  Twitter for Android      False
#
# [161251 rows x 13 columns]

# %% [markdown]
# Check the number of `NaN` value in each column.

# %%
df.isnull().sum(axis = 0)
# Out:
# user_name               4
# user_location       32831
# user_description     9142
# user_created            4
# user_followers          5
# user_friends            5
# user_favourites         5
# user_verified           5
# date                    6
# text                    5
# hashtags            51520
# source                153
# is_retweet             10
# dtype: int64

# %% [markdown]
# Check the date type for each column.

# %%
df.dtypes
# Out:
# user_name            object
# user_location        object
# user_description     object
# user_created         object
# user_followers      float64
# user_friends         object
# user_favourites      object
# user_verified        object
# date                 object
# text                 object
# hashtags             object
# source               object
# is_retweet           object
# dtype: object

# %% [markdown]
# Convert the columns to correct data types.

# %%
numeric_cols = ['user_followers', 'user_friends', 'user_favourites']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

df['user_verified'] = df['user_verified'].astype(bool)
df['is_retweet'] = df['is_retweet'].astype(bool)

df
# Out:
#                                  user_name              user_location  \
# 0                                 MyNewsNE                      Assam
# 1                            Shubham Gupta                        NaN
# 2                  Journal of Infectiology                        NaN
# 3                                     Zane                        NaN
# 4                       Ann-Maree O’Connor  Adelaide, South Australia
# ...                                    ...                        ...
# 161246         Multivalent Dirk Haussecker                  RNA World
# 161247                    Craig Brown 🏳️‍🌈        Melbourne, Victoria
# 161248                   Faith in New York              New York, USA
# 161249  Openly Black & Queer & Adrian 🎵🎬⚖️                  In My Bag
# 161250                                 ⛄️🌈         SA & NT (rotation)
#
#                                          user_description  \
# 0       MyNewsNE a dedicated multi-lingual media house...
# 1       I will tell about all experiences of my life f...
# 2       Journal of Infectiology (ISSN 2689-9981) is ac...
# 3                                       Fresher than you.
# 4       Retired university administrator. Melburnian b...
# ...                                                   ...
# 161246  Biotech stock addict. Trained in RNAi. Love gr...
# 161247  writer. dad. husband. exvangelical. type 1. le...
# 161248  Building power in New York faith institutions ...
# 161249  CashApp $inga4hire 💰 // #MeToo Fellow //Spelma...
# 161250  The message is in the 'demeaning'.\nQuality co...
#
#                user_created  user_followers  user_friends  user_favourites  \
# 0          24-05-2020 10:18            64.0          11.0            110.0
# 1          14-08-2020 16:42             1.0          17.0              0.0
# 2          14-12-2017 07:07           143.0         566.0              8.0
# 3          18-09-2019 11:01            29.0          25.0            620.0
# 4          24-01-2013 14:53            83.0         497.0          10737.0
# ...                     ...             ...           ...              ...
# 161246  2011-11-10 12:00:58         11708.0         371.0           9176.0
# 161247  2012-06-20 16:47:27           397.0         838.0           9927.0
# 161248  2013-06-04 21:34:33          3122.0        2569.0           6663.0
# 161249  2009-09-16 15:33:00           460.0         523.0          30867.0
# 161250  2020-02-02 06:45:45           399.0         375.0          14188.0
#
#         user_verified                 date  \
# 0                True     18-08-2020 12:55
# 1                True     18-08-2020 12:55
# 2                True     18-08-2020 12:46
# 3                True     18-08-2020 12:45
# 4                True     18-08-2020 12:45
# ...               ...                  ...
# 161246          False  2021-03-11 22:30:23
# 161247          False  2021-03-11 22:30:05
# 161248          False  2021-03-11 22:29:58
# 161249          False  2021-03-11 22:29:56
# 161250          False  2021-03-11 22:29:54
#
#                                                      text  \
# 0       Australia to Manufacture Covid-19 Vaccine and ...
# 1       #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2       Deaths due to COVID-19 in Affected Countries\n...
# 3       @Team_Subhashree @subhashreesotwe @iamrajchoco...
# 4       @michellegrattan @ConversationEDU This is what...
# ...                                                   ...
# 161246  $ABUS totally missing in action. Nothing on mR...
# 161247  “It’s not a race,” says man already vaccinated...
# 161248  ⚠️PSA FOR COVID-19 VACCINE⚠️\n\nIf you live in...
# 161249  My doctor: Like to schedule your #CovidVaccine...
# 161250  @M_McCormackMP serves up a litany of excuses f...
#
#                                                  hashtags  \
# 0                                        ['CovidVaccine']
# 1       ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 161246                       ['covidvaccine', 'sarscov2']
# 161247  ['vaccine', 'auspol', 'CovidVaccine', 'ScottyF...
# 161248                                ['Bronx', 'Harlem']
# 161249                                   ['CovidVaccine']
# 161250                        ['LNPfail', 'CovidVaccine']
#
#                      source  is_retweet
# 0           Twitter Web App       False
# 1       Twitter for Android       False
# 2           Twitter Web App       False
# 3       Twitter for Android       False
# 4           Twitter Web App       False
# ...                     ...         ...
# 161246      Twitter Web App       False
# 161247   Twitter for iPhone       False
# 161248   Twitter for iPhone       False
# 161249  Twitter for Android       False
# 161250  Twitter for Android       False
#
# [161251 rows x 13 columns]

# %% [markdown]
# Convert `['user_created']` and `['date']` columns into `datetime` format and check any invalid values

# %%
# Convert format for 'user_created' column
series = df['user_created']

# Convert different formats of strings into datetime
one = pd.to_datetime(series, format='%d-%m-%Y %H:%M', errors='coerce')
two = pd.to_datetime(series, format='%d-%m-%Y %H:%M:S', errors='coerce')
three = pd.to_datetime(series, format='%Y-%m-%d %H:%M', errors='coerce')
four = pd.to_datetime(series, format='%Y-%m-%d %H:%M:S', errors='coerce')

# Fill the new column 
new_series = one.fillna(two).fillna(three).fillna(four)

# Check if any other 
print("Overlooked format and/or invalid values in the 'user_created' column: ")
print(series[new_series.isna()])

# Reassign the new_series to the column
df['user_created'] = new_series
# Out:
# Overlooked format and/or invalid values in the 'user_created' column:
# 23986     False
# 27430       NaN
# 27431       932
# 45326       NaN
# 45327       378
# 64305       NaN
# 64306       747
# 110775      NaN
# 110776       75
# Name: user_created, dtype: object

# %%
# Convert format for 'date' column
series = df['date']

# Convert different formats of strings into datetime
one = pd.to_datetime(series, format='%d-%m-%Y %H:%M', errors='coerce')
two = pd.to_datetime(series, format='%d-%m-%Y %H:%M:S', errors='coerce')
three = pd.to_datetime(series, format='%Y-%m-%d %H:%M', errors='coerce')
four = pd.to_datetime(series, format='%Y-%m-%d %H:%M:S', errors='coerce')

# Fill the new column 
new_series = one.fillna(two).fillna(three).fillna(four)

# Check if any other 
print("Overlooked format and/or invalid values in the 'date' column: ")
print(series[new_series.isna()])

# Reassign the new_series to the column
df['date'] = new_series
# Out:
# Overlooked format and/or invalid values in the 'date' column:
# 23986                                                   NaN
# 27430                                                   NaN
# 27431     ['southafricancoronavirus', 'CovidVaccine', 'l...
# 45326                                                   NaN
# 45327                                                   NaN
# 64305                                                   NaN
# 64306                                      ['CovidVaccine']
# 110775                                                  NaN
# 110776    ['SickleCell', 'thalassaemia', 'COVID19', 'Cov...
# Name: date, dtype: object

# %% [markdown]
# Drop rows with `NaN` in `['user_created, 'date']`.

# %%
df = df.dropna(subset=['user_created', 'date'])
df
# Out:
#                                  user_name              user_location  \
# 0                                 MyNewsNE                      Assam
# 1                            Shubham Gupta                        NaN
# 2                  Journal of Infectiology                        NaN
# 3                                     Zane                        NaN
# 4                       Ann-Maree O’Connor  Adelaide, South Australia
# ...                                    ...                        ...
# 161246         Multivalent Dirk Haussecker                  RNA World
# 161247                    Craig Brown 🏳️‍🌈        Melbourne, Victoria
# 161248                   Faith in New York              New York, USA
# 161249  Openly Black & Queer & Adrian 🎵🎬⚖️                  In My Bag
# 161250                                 ⛄️🌈         SA & NT (rotation)
#
#                                          user_description        user_created  \
# 0       MyNewsNE a dedicated multi-lingual media house... 2020-05-24 10:18:00
# 1       I will tell about all experiences of my life f... 2020-08-14 16:42:00
# 2       Journal of Infectiology (ISSN 2689-9981) is ac... 2017-12-14 07:07:00
# 3                                       Fresher than you. 2019-09-18 11:01:00
# 4       Retired university administrator. Melburnian b... 2013-01-24 14:53:00
# ...                                                   ...                 ...
# 161246  Biotech stock addict. Trained in RNAi. Love gr... 2011-11-10 12:00:58
# 161247  writer. dad. husband. exvangelical. type 1. le... 2012-06-20 16:47:27
# 161248  Building power in New York faith institutions ... 2013-06-04 21:34:33
# 161249  CashApp $inga4hire 💰 // #MeToo Fellow //Spelma... 2009-09-16 15:33:00
# 161250  The message is in the 'demeaning'.\nQuality co... 2020-02-02 06:45:45
#
#         user_followers  user_friends  user_favourites  user_verified  \
# 0                 64.0          11.0            110.0           True
# 1                  1.0          17.0              0.0           True
# 2                143.0         566.0              8.0           True
# 3                 29.0          25.0            620.0           True
# 4                 83.0         497.0          10737.0           True
# ...                ...           ...              ...            ...
# 161246         11708.0         371.0           9176.0          False
# 161247           397.0         838.0           9927.0          False
# 161248          3122.0        2569.0           6663.0          False
# 161249           460.0         523.0          30867.0          False
# 161250           399.0         375.0          14188.0          False
#
#                       date                                               text  \
# 0      2020-08-18 12:55:00  Australia to Manufacture Covid-19 Vaccine and ...
# 1      2020-08-18 12:55:00  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2      2020-08-18 12:46:00  Deaths due to COVID-19 in Affected Countries\n...
# 3      2020-08-18 12:45:00  @Team_Subhashree @subhashreesotwe @iamrajchoco...
# 4      2020-08-18 12:45:00  @michellegrattan @ConversationEDU This is what...
# ...                    ...                                                ...
# 161246 2021-03-11 22:30:23  $ABUS totally missing in action. Nothing on mR...
# 161247 2021-03-11 22:30:05  “It’s not a race,” says man already vaccinated...
# 161248 2021-03-11 22:29:58  ⚠️PSA FOR COVID-19 VACCINE⚠️\n\nIf you live in...
# 161249 2021-03-11 22:29:56  My doctor: Like to schedule your #CovidVaccine...
# 161250 2021-03-11 22:29:54  @M_McCormackMP serves up a litany of excuses f...
#
#                                                  hashtags  \
# 0                                        ['CovidVaccine']
# 1       ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 161246                       ['covidvaccine', 'sarscov2']
# 161247  ['vaccine', 'auspol', 'CovidVaccine', 'ScottyF...
# 161248                                ['Bronx', 'Harlem']
# 161249                                   ['CovidVaccine']
# 161250                        ['LNPfail', 'CovidVaccine']
#
#                      source  is_retweet
# 0           Twitter Web App       False
# 1       Twitter for Android       False
# 2           Twitter Web App       False
# 3       Twitter for Android       False
# 4           Twitter Web App       False
# ...                     ...         ...
# 161246      Twitter Web App       False
# 161247   Twitter for iPhone       False
# 161248   Twitter for iPhone       False
# 161249  Twitter for Android       False
# 161250  Twitter for Android       False
#
# [161242 rows x 13 columns]

# %% [markdown]
# Dropping rows with `NaN` in `['user_created, 'date']` turns out to be dropping rows with `NaN` in `['user_followers', 'user_friends', 'user_favourites', user_verified', 'text, 'is_retweet]`.

# %%
df.isnull().sum(axis = 0)
# Out:
# user_name               4
# user_location       32831
# user_description     9142
# user_created            0
# user_followers          0
# user_friends            0
# user_favourites         0
# user_verified           0
# date                    0
# text                    0
# hashtags            51515
# source                144
# is_retweet              0
# dtype: int64

# %% [markdown]
# Keep only data up until 2021/02/28 23:59:59.

# %%
df = df[df['date'] < '2021-03-01 00:00:00']
df
# Out:
#                           user_name              user_location  \
# 0                          MyNewsNE                      Assam
# 1                     Shubham Gupta                        NaN
# 2           Journal of Infectiology                        NaN
# 3                              Zane                        NaN
# 4                Ann-Maree O’Connor  Adelaide, South Australia
# ...                             ...                        ...
# 154542                       Dawn B                        NaN
# 154543  crippled carrie bradshaw ♿️    Eric Foreman's Basement
# 154544                vaccinesearch                        NaN
# 154545    Dolores Huerta Foundation         Central Valley, CA
# 154546                vaccinesearch                        NaN
#
#                                          user_description        user_created  \
# 0       MyNewsNE a dedicated multi-lingual media house... 2020-05-24 10:18:00
# 1       I will tell about all experiences of my life f... 2020-08-14 16:42:00
# 2       Journal of Infectiology (ISSN 2689-9981) is ac... 2017-12-14 07:07:00
# 3                                       Fresher than you. 2019-09-18 11:01:00
# 4       Retired university administrator. Melburnian b... 2013-01-24 14:53:00
# ...                                                   ...                 ...
# 154542                                                NaN 2011-09-21 16:03:12
# 154543  what are you doing in my swamp?  just a lil fi... 2011-03-10 13:12:31
# 154544  Hit Me With Your Best Shot - Pat Benatar. Tale... 2021-02-18 06:03:14
# 154545  Organizes at the grassroots level by engaging ... 2014-03-27 20:36:48
# 154546  Hit Me With Your Best Shot - Pat Benatar. Tale... 2021-02-18 06:03:14
#
#         user_followers  user_friends  user_favourites  user_verified  \
# 0                 64.0          11.0            110.0           True
# 1                  1.0          17.0              0.0           True
# 2                143.0         566.0              8.0           True
# 3                 29.0          25.0            620.0           True
# 4                 83.0         497.0          10737.0           True
# ...                ...           ...              ...            ...
# 154542            13.0          61.0            762.0          False
# 154543           448.0         344.0           3340.0          False
# 154544            83.0          39.0             81.0          False
# 154545          4170.0         271.0            649.0          False
# 154546            83.0          39.0             81.0          False
#
#                       date                                               text  \
# 0      2020-08-18 12:55:00  Australia to Manufacture Covid-19 Vaccine and ...
# 1      2020-08-18 12:55:00  #CoronavirusVaccine #CoronaVaccine #CovidVacci...
# 2      2020-08-18 12:46:00  Deaths due to COVID-19 in Affected Countries\n...
# 3      2020-08-18 12:45:00  @Team_Subhashree @subhashreesotwe @iamrajchoco...
# 4      2020-08-18 12:45:00  @michellegrattan @ConversationEDU This is what...
# ...                    ...                                                ...
# 154542 2021-02-26 00:03:57  Did you know you need an ID to get the COVID v...
# 154543 2021-02-26 00:01:12  I didn’t know I could be this excited to get a...
# 154544 2021-02-26 00:01:12  ANDERSON, South Carolina\nBENNETTSVILLE \nBISH...
# 154545 2021-02-26 00:00:48  #FRESNOCOUNTY: Find out if you're eligible for...
# 154546 2021-02-26 00:00:27  These are LIVE!\n\nEWA BEACH, Hawaii\nHONOLULU...
#
#                                                  hashtags  \
# 0                                        ['CovidVaccine']
# 1       ['CoronavirusVaccine', 'CoronaVaccine', 'Covid...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 154542    ['COVID19', 'COVIDVaccine', 'COVIDVaccination']
# 154543                                                NaN
# 154544                                                NaN
# 154545                                   ['FRESNOCOUNTY']
# 154546                                                NaN
#
#                      source  is_retweet
# 0           Twitter Web App       False
# 1       Twitter for Android       False
# 2           Twitter Web App       False
# 3       Twitter for Android       False
# 4           Twitter Web App       False
# ...                     ...         ...
# 154542     Twitter for iPad       False
# 154543   Twitter for iPhone       False
# 154544      Twitter Web App       False
# 154545       Hootsuite Inc.       False
# 154546      Twitter Web App       False
#
# [154538 rows x 13 columns]

# %% [markdown]
# Sort the data based on `['date']` in ascending order.

# %%
df = df.sort_values(by=['date']).reset_index(drop=True)
df
# Out:
#                              user_name               user_location  \
# 0                               Ashwin                    India 🇮🇳
# 1                        K. Kartik Rao     Mumbai and Nagpur India
# 2       Mac Patrick (Road Hater) Henry       German Bundesrepublik
# 3                           lydia Bell                      Earth
# 4                      Lou Ann Donovan                 Kansas, USA
# ...                                ...                         ...
# 154533          Script Your Future '21                         DMV
# 154534                  eastvillagetwt  East Village, New York, NY
# 154535                          Yogita                New York, NY
# 154536                             DrZ                         USA
# 154537                   vaccinesearch                         NaN
#
#                                          user_description        user_created  \
# 0       I'm Just A Man On a Mission For My Vision!\n\n... 2018-01-08 06:01:00
# 1       Actor 🎭 \n\nhttps://t.co/u7GZfoWBDt\n\nSubscri... 2016-12-10 16:06:00
# 2       Liberty lover. \nServing the people of the 🇺🇸.... 2014-01-11 19:47:00
# 3       Mummy, animal lover , energy worker , awake in... 2009-03-23 01:09:00
# 4       Live Young Look Young BE Young! Certified Inte... 2009-03-17 05:42:00
# ...                                                   ...                 ...
# 154533  HowardU and Script Your Future has joined forc... 2021-01-31 18:40:41
# 154534  Politics, the environment, science, culture, t... 2011-08-27 19:24:17
# 154535  Primum non nocere 💕👩🏽‍⚕️ | Tweets are my own. ... 2015-08-07 01:48:57
# 154536                                                NaN 2016-03-23 13:00:36
# 154537  Hit Me With Your Best Shot - Pat Benatar. Tale... 2021-02-18 06:03:14
#
#         user_followers  user_friends  user_favourites  user_verified  \
# 0                 89.0        3108.0           6780.0           True
# 1                225.0         257.0          25362.0           True
# 2                338.0         277.0          28305.0           True
# 3               2038.0        1105.0          63422.0           True
# 4               4365.0        4581.0           2505.0           True
# ...                ...           ...              ...            ...
# 154533            15.0          42.0              4.0          False
# 154534          1968.0        5001.0         136110.0          False
# 154535            17.0          58.0           1194.0          False
# 154536            54.0           4.0              4.0          False
# 154537            83.0          39.0             81.0          False
#
#                       date                                               text  \
# 0      2020-08-09 19:15:00  Huge Thanks And Best Wishes With @SerumInstInd...
# 1      2020-08-09 20:02:00                   Any update of #CovidVaccine ????
# 2      2020-08-09 21:21:00  From a private frontline COVID nurses group to...
# 3      2020-08-09 21:29:00  So you want the whole world to take a #covidva...
# 4      2020-08-09 22:55:00  Watch to learn about the Phase 3 clinical tria...
# ...                    ...                                                ...
# 154533 2021-02-28 23:55:25  * Continue with routine preventive measures (s...
# 154534 2021-02-28 23:56:37  COVID: California Suspends System Of Shared Va...
# 154535 2021-02-28 23:57:00  Today I got my first dose of the #COVIDVaccine...
# 154536 2021-02-28 23:57:06  Here's Where to Receive a COVID Vaccine in Ill...
# 154537 2021-02-28 23:57:15  Utah!! SLC is sold out. Walmart vaccine. **onl...
#
#                                                  hashtags  \
# 0                                          ['COVISHEILD']
# 1                                        ['CovidVaccine']
# 2       ['COVID19', 'CovidVaccineRace', 'CovidVaccine'...
# 3                                        ['covidvaccine']
# 4       ['COVID19', 'CovidVaccine', 'CovidClinicalTrial']
# ...                                                   ...
# 154533                                                NaN
# 154534                        ['COVID19', 'COVIDVaccine']
# 154535                                   ['COVIDVaccine']
# 154536                       ['Illinois', 'COVIDvaccine']
# 154537                                                NaN
#
#                      source  is_retweet
# 0       Twitter for Android       False
# 1       Twitter for Android       False
# 2           Twitter Web App       False
# 3        Twitter for iPhone       False
# 4        Twitter for iPhone       False
# ...                     ...         ...
# 154533      Twitter Web App       False
# 154534   Twitter for iPhone       False
# 154535  Twitter for Android       False
# 154536               Buffer       False
# 154537      Twitter Web App       False
#
# [154538 rows x 13 columns]

# %% [markdown]
# Write the cleaned data to `covidvaccine.csv`.

# %%
df.to_csv(os.path.join(data_root, 'covidvaccine.csv'), index=False)

# %% [markdown]
# See how the tweets are distributed across time.

# %%
count_by_month = df['date'].groupby(df.date.dt.to_period("M")).agg('count')
ax = count_by_month.plot(kind='bar')
ax.set_xlabel("Months")
ax.set_ylabel("Tweet Count by Months")
# Out:
# Text(0, 0.5, 'Tweet Count by Months')
